# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
# %matplotlib inline

# %%
Network=pd.read_csv(r'C:\Users\rishi\Desktop\eHealth Test\health-insurance-marketplace\Network.csv')
Network.head(n=15)
# Out:
#     BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0           2014        AK     21989       HIOS           6
# 1           2014        AK     38344       HIOS           6
# 2           2014        AK     38536       HIOS           2
# 3           2014        AK     42507       HIOS           3
# 4           2014        AK     73836       HIOS           6
# 5           2014        AK     73836       HIOS           6
# 6           2014        AK     74819       HIOS           7
# 7           2014        AK     84859       HIOS           1
# 8           2014        AL     12538       HIOS           8
# 9           2014        AL     12538       HIOS           8
# 10          2014        AL     17540       HIOS           3
# 11          2014        AL     44580       HIOS          10
# 12          2014        AL     44580       HIOS          10
# 13          2014        AL     44580       HIOS          10
# 14          2014        AL     44785       HIOS           4
#
# ...

# %%
df=Network[['BusinessYear','StateCode','NetworkName']].groupby('StateCode')

# %%
df1=df.apply(lambda _df: _df[_df['BusinessYear']==2016])
df2=df1[['NetworkName']].groupby('StateCode').nunique().sort_values('NetworkName', ascending=False).head(n=10)
df2
# Out:
#            NetworkName
# StateCode
# TX                  68
# PA                  59
# IL                  57
# OH                  56
# MI                  56
# FL                  55
# WI                  53
# GA                  49
# MO                  47
# VA                  47

# %%
df2.plot.bar()
